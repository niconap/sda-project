# %%
# Put the imports here, this makes it easy to create a requirements.txt file
# later, which can be used by whoever is grading us to install everything!
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
from itertools import combinations

# %%
# Reading the CSV file into a DataFrame
file_path = 'alzheimers_disease_data.csv'  # Replace with your file path if different
alzheimers_data = pd.read_csv(file_path)

# %%
internal_factors_keys = [
    "Age", "Gender", "Ethnicity", "BMI", "FamilyHistoryAlzheimers",
    "CardiovascularDisease", "Diabetes", "Depression", "Hypertension",
    "SystolicBP", "DiastolicBP", "CholesterolTotal", "CholesterolLDL",
    "CholesterolHDL", "CholesterolTriglycerides", "MMSE", "FunctionalAssessment",
    "MemoryComplaints", "BehavioralProblems", "ADL", "Confusion",
    "Disorientation", "PersonalityChanges", "DifficultyCompletingTasks",
    "Forgetfulness", "HeadInjury"
]
external_factors_keys = ["EducationLevel", "Smoking", "AlcoholConsumption",
                         "PhysicalActivity", "DietQuality", "SleepQuality"]

# %%
df = alzheimers_data
df.columns = df.columns.str.strip()

# %% [markdown]
# Logistic regression:
#
# we need to use forward modelling selection with the usage of BIC

# %%
#logistic regression model with ['MemoryComplaints', 'BehavioralProblems', 'MMSE', 'ADL', 'FunctionalAssessment']

# Define the target variable (Diagnosis) and predictor variables (X)
y = alzheimers_data['Diagnosis'].astype(int)  # Ensure target variable is numeric

# You can add a constant (intercept) term to the predictor variables:
X = alzheimers_data[['MemoryComplaints', 'BehavioralProblems', 'MMSE', 'ADL', 'FunctionalAssessment']]
X_sm = sm.add_constant(X)  # Add a constant for the intercept term

# Fit the logistic regression model
model = sm.Logit(y, X_sm).fit()

print(model.summary())

# Get the BIC value for the model
bic_value = model.bic

# Print the BIC value
print(f"BIC value for the given model: {bic_value}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.374126
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Diagnosis   No. Observations:                 2149
# Model:                          Logit   Df Residuals:                     2143
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 05 Dec 2024   Pseudo R-squ.:                  0.4241
# Time:                        09:12:55   Log-Likelihood:                -804.00
# converged:                       True   LL-Null:                       -1396.2
# Covariance Type:            nonrobust   LLR p-value:                7.292e-254
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    3.8610      0.231     16.684      0.000       3.407       4.315
# MemoryComplaints         2.5896      0.165     15.711      0.000       2.266       2.913
# BehavioralProblems       2.4733      0.181     13.676      0.000       2.119       2.828
# MMSE                    -0.1072      0.008    -13.280      0.000      -0.123      -0.091
# ADL                     -0.4139      0.026    -16.230      0.000      -0.464      -0.364
# FunctionalAssessment    -0.4441      0.026    -17.095      0.000      -0.495      -0.393
# ========================================================================================
# BIC value for the given model: 1654.0285326599942

# %% [markdown]
# Takes the predictors and calculates which model is the best with the use of BIC. The code below looks at the variables and adds the one with the best (lowest) BIC score. It keeps on doing this until it cannot imnprove the BIC score anymore. Then, it adds the remaining variables so you can see in the graph that the BIC score gets worse the more variables you add from that point on.

# %%
# Define the target variable (Diagnosis) and predictor variables 
y = alzheimers_data['Diagnosis'].astype(int)  # Ensure target variable is numeric

# Create a list of all potential predictor variables
predictors = internal_factors_keys + external_factors_keys

# Function to fit logistic regression and calculate BIC
def fit_model(X):
    X_sm = sm.add_constant(X)  # Add a constant for the intercept term
    model_sm = sm.Logit(y, X_sm).fit(disp=0)  # Fit the logistic regression model
    return model_sm.bic, model_sm  # Return the BIC value and model

# Function to print the logistic regression formula
def print_model_formula(model, predictors):
    coef = model.params
    formula = f"y = {coef.iloc[0]:.4f}"  # Intercept
    for i, predictor in enumerate(predictors):
        formula += f" + ({coef.iloc[i + 1]:.4f} * {predictor})"
    print("Logistic Regression Formula:")
    print(formula)

# Initialize lists to store the BIC values and the predictors used
bic_values = []
best_bic = float('inf')
best_model = None
selected_predictors = []
remaining_predictors = set(predictors)

# Step 1: Find the best initial predictor
best_initial_bic = float('inf')
best_initial_predictor = None

for predictor in remaining_predictors:
    X = alzheimers_data[[predictor]]
    bic, _ = fit_model(X)
    if bic < best_initial_bic:
        best_initial_bic = bic
        best_initial_predictor = predictor

# Update lists and variables after selecting the first predictor
selected_predictors.append(best_initial_predictor)
bic_values.append(best_initial_bic)
best_bic = best_initial_bic
remaining_predictors.remove(best_initial_predictor)

# Step 2: Iteratively add predictors that improve the BIC
while remaining_predictors:
    best_new_bic = float('inf')
    best_new_predictor = None

    for predictor in remaining_predictors:
        X = alzheimers_data[selected_predictors + [predictor]]
        bic, _ = fit_model(X)
        if bic < best_new_bic:
            best_new_bic = bic
            best_new_predictor = predictor

    # Check if adding the new predictor improves the BIC
    if best_new_bic < best_bic:
        best_bic = best_new_bic
        selected_predictors.append(best_new_predictor)
        bic_values.append(best_bic)
        remaining_predictors.remove(best_new_predictor)

        # Save the current best model
        X_best = alzheimers_data[selected_predictors]
        X_best_sm = sm.add_constant(X_best)
        _, best_model = fit_model(X_best)
    else:
        break  # Stop if no improvement

# Step 3: Add remaining predictors to complete the graph
for predictor in remaining_predictors:
    selected_predictors.append(predictor)
    X = alzheimers_data[selected_predictors]
    bic, _ = fit_model(X)
    bic_values.append(bic)

# Print the best combination of predictors and its BIC
print(f"Best combination of predictors: {selected_predictors[:bic_values.index(best_bic) + 1]}")
print(f"Best BIC: {best_bic}")

# Print the summary of the best model
print(best_model.summary())

# Print the logistic regression formula for the best model
print_model_formula(best_model, selected_predictors[:bic_values.index(best_bic) + 1])

# Visualization: Plot the number of predictors vs BIC values
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(bic_values) + 1), bic_values, marker='o', linestyle='-', color='b')
plt.title('BIC vs Number of Predictors')
plt.xlabel('Number of Predictors')
plt.ylabel('BIC')
plt.xticks(range(1, len(bic_values) + 1))
plt.axvline(x=bic_values.index(best_bic) + 1, color='r', linestyle='--', label='Best Model')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Best combination of predictors: ['FunctionalAssessment', 'ADL', 'MemoryComplaints', 'BehavioralProblems', 'MMSE']
# Best BIC: 1654.0285326599942
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Diagnosis   No. Observations:                 2149
# Model:                          Logit   Df Residuals:                     2143
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 04 Dec 2024   Pseudo R-squ.:                  0.4241
# Time:                        19:12:56   Log-Likelihood:                -804.00
# converged:                       True   LL-Null:                       -1396.2
# Covariance Type:            nonrobust   LLR p-value:                7.292e-254
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    3.8610      0.231     16.684      0.000       3.407       4.315
# FunctionalAssessment    -0.4441      0.026    -17.095      0.000      -0.495      -0.393
# ADL                     -0.4139      0.026    -16.230      0.000      -0.464      -0.364
# MemoryComplaints         2.5896      0.165     15.711      0.000       2.266       2.913
# BehavioralProblems       2.4733      0.181     13.676      0.000       2.119       2.828
# MMSE                    -0.1072      0.008    -13.280      0.000      -0.123      -0.091
# ========================================================================================
# Logistic Regression Formula:
# y = 3.8610 + (-0.4441 * FunctionalAssessment) + (-0.4139 * ADL) + (2.5896 * MemoryComplaints) + (2.4733 * BehavioralProblems) + (-0.1072 * MMSE)

# %% [markdown]
# From here on, the same is done but the columns are seperated based on the ethnicity. So per column, 4 new columns are added (for ethnicity 0-3)

# %%
df_2 = alzheimers_data

# %%
#combine all predictors
all_predictors = internal_factors_keys + external_factors_keys

# %%
# Initialize the list
predictors_on_ethnicity = []

# Create subset columns and add their names to the list
for predictor in all_predictors:
    for ethnicity in df_2['Ethnicity'].unique():
        col_name = f'{predictor}_{ethnicity}'
        df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
        predictors_on_ethnicity.append(col_name)  # Add to the list
# Out:
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)
# /var/folders/1p/_qsgjt295zvdn826n1c5sy700000gn/T/ipykernel_1019/2322659114.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2[col_name] = df_2.loc[df_2['Ethnicity'] == ethnicity, predictor].fillna(0)

# %%
def write_df_to_csv(df, file_name):
    """
    Writes the provided DataFrame to a CSV file.
    
    Parameters:
    df (pandas.DataFrame): The DataFrame to write.
    file_name (str): The name of the CSV file to save the DataFrame.
    """
    df.to_csv(file_name, index=False)  # index=False prevents writing row indices
    print(f"DataFrame successfully written to {file_name}")

# %%
write_df_to_csv(df_2, 'analysis.csv')
# Out:
# DataFrame successfully written to analysis.csv

# %% [markdown]
# The code below fills in all the Nan in the dataframe. It does this by firstly iterating over all columns. In the column, it checks if there are any Nan. If it finds a Nan, it looks at the diagnosis of the row. Then, it takes a random value out of that column with the same diagnosis score and fills it in.

# %%
#fill in the Nan by randomly replacing it by another value of that column, but checking if the 'diagnosis' value is the same of the one that it replaces it with


def random_impute_by_diagnosis(df, column, diagnosis_column='Diagnosis'):
    # Iterate over each row in the dataframe
    for idx, row in df.iterrows():
        # If the current column has a NaN value
        if pd.isna(row[column]):
            # Get the Diagnosis value of the current row
            diagnosis_value = row[diagnosis_column]
            
            # Filter the dataframe for rows with the same Diagnosis value
            subset = df[df[diagnosis_column] == diagnosis_value]
            
            # Get the non-NaN values of the current column from the subset
            non_missing_values = subset[column].dropna().values
            
            # If there are any non-NaN values to sample from
            if len(non_missing_values) > 0:
                # Randomly select a value from the non-missing values
                random_value = np.random.choice(non_missing_values)
                
                # Replace the NaN with the randomly selected value
                df.at[idx, column] = random_value
    
    # After finishing the column, print a success message
    print(f"Imputation for column '{column}' completed successfully.")
    return df

# %%
columns = df_2.columns
for column in columns:
    df_2 = random_impute_by_diagnosis(df_2, column)

#this took 30 minutes
# Out:
# Imputation for column 'PatientID' completed successfully.
# Imputation for column 'Age' completed successfully.
# Imputation for column 'Gender' completed successfully.
# Imputation for column 'Ethnicity' completed successfully.
# Imputation for column 'EducationLevel' completed successfully.
# Imputation for column 'BMI' completed successfully.
# Imputation for column 'Smoking' completed successfully.
# Imputation for column 'AlcoholConsumption' completed successfully.
# Imputation for column 'PhysicalActivity' completed successfully.
# Imputation for column 'DietQuality' completed successfully.
# Imputation for column 'SleepQuality' completed successfully.
# Imputation for column 'FamilyHistoryAlzheimers' completed successfully.
# Imputation for column 'CardiovascularDisease' completed successfully.
# Imputation for column 'Diabetes' completed successfully.
# Imputation for column 'Depression' completed successfully.
# Imputation for column 'HeadInjury' completed successfully.
# Imputation for column 'Hypertension' completed successfully.
# Imputation for column 'SystolicBP' completed successfully.
# Imputation for column 'DiastolicBP' completed successfully.
# Imputation for column 'CholesterolTotal' completed successfully.
# Imputation for column 'CholesterolLDL' completed successfully.
# Imputation for column 'CholesterolHDL' completed successfully.
# Imputation for column 'CholesterolTriglycerides' completed successfully.
# Imputation for column 'MMSE' completed successfully.
# Imputation for column 'FunctionalAssessment' completed successfully.
# Imputation for column 'MemoryComplaints' completed successfully.
# Imputation for column 'BehavioralProblems' completed successfully.
# Imputation for column 'ADL' completed successfully.
# Imputation for column 'Confusion' completed successfully.
# Imputation for column 'Disorientation' completed successfully.
# Imputation for column 'PersonalityChanges' completed successfully.
# Imputation for column 'DifficultyCompletingTasks' completed successfully.
# Imputation for column 'Forgetfulness' completed successfully.
# Imputation for column 'Diagnosis' completed successfully.
# Imputation for column 'DoctorInCharge' completed successfully.
# Imputation for column 'Age_0' completed successfully.
# Imputation for column 'Age_3' completed successfully.
# Imputation for column 'Age_1' completed successfully.
# Imputation for column 'Age_2' completed successfully.
# Imputation for column 'Gender_0' completed successfully.
# Imputation for column 'Gender_3' completed successfully.
# Imputation for column 'Gender_1' completed successfully.
# Imputation for column 'Gender_2' completed successfully.
# Imputation for column 'Ethnicity_0' completed successfully.
# Imputation for column 'Ethnicity_3' completed successfully.
# Imputation for column 'Ethnicity_1' completed successfully.
# Imputation for column 'Ethnicity_2' completed successfully.
# Imputation for column 'BMI_0' completed successfully.
# Imputation for column 'BMI_3' completed successfully.
# Imputation for column 'BMI_1' completed successfully.
# Imputation for column 'BMI_2' completed successfully.
# Imputation for column 'FamilyHistoryAlzheimers_0' completed successfully.
# Imputation for column 'FamilyHistoryAlzheimers_3' completed successfully.
# Imputation for column 'FamilyHistoryAlzheimers_1' completed successfully.
# Imputation for column 'FamilyHistoryAlzheimers_2' completed successfully.
# Imputation for column 'CardiovascularDisease_0' completed successfully.
# Imputation for column 'CardiovascularDisease_3' completed successfully.
# Imputation for column 'CardiovascularDisease_1' completed successfully.
# Imputation for column 'CardiovascularDisease_2' completed successfully.
# Imputation for column 'Diabetes_0' completed successfully.
# Imputation for column 'Diabetes_3' completed successfully.
# Imputation for column 'Diabetes_1' completed successfully.
# Imputation for column 'Diabetes_2' completed successfully.
# Imputation for column 'Depression_0' completed successfully.
# Imputation for column 'Depression_3' completed successfully.
# Imputation for column 'Depression_1' completed successfully.
# Imputation for column 'Depression_2' completed successfully.
# Imputation for column 'Hypertension_0' completed successfully.
# Imputation for column 'Hypertension_3' completed successfully.
# Imputation for column 'Hypertension_1' completed successfully.
# Imputation for column 'Hypertension_2' completed successfully.
# Imputation for column 'SystolicBP_0' completed successfully.
# Imputation for column 'SystolicBP_3' completed successfully.
# Imputation for column 'SystolicBP_1' completed successfully.
# Imputation for column 'SystolicBP_2' completed successfully.
# Imputation for column 'DiastolicBP_0' completed successfully.
# Imputation for column 'DiastolicBP_3' completed successfully.
# Imputation for column 'DiastolicBP_1' completed successfully.
# Imputation for column 'DiastolicBP_2' completed successfully.
# Imputation for column 'CholesterolTotal_0' completed successfully.
# Imputation for column 'CholesterolTotal_3' completed successfully.
# Imputation for column 'CholesterolTotal_1' completed successfully.
# Imputation for column 'CholesterolTotal_2' completed successfully.
# Imputation for column 'CholesterolLDL_0' completed successfully.
# Imputation for column 'CholesterolLDL_3' completed successfully.
# Imputation for column 'CholesterolLDL_1' completed successfully.
# Imputation for column 'CholesterolLDL_2' completed successfully.
# Imputation for column 'CholesterolHDL_0' completed successfully.
# Imputation for column 'CholesterolHDL_3' completed successfully.
# Imputation for column 'CholesterolHDL_1' completed successfully.
# Imputation for column 'CholesterolHDL_2' completed successfully.
# Imputation for column 'CholesterolTriglycerides_0' completed successfully.
# Imputation for column 'CholesterolTriglycerides_3' completed successfully.
# Imputation for column 'CholesterolTriglycerides_1' completed successfully.
# Imputation for column 'CholesterolTriglycerides_2' completed successfully.
# Imputation for column 'MMSE_0' completed successfully.
# Imputation for column 'MMSE_3' completed successfully.
# Imputation for column 'MMSE_1' completed successfully.
# Imputation for column 'MMSE_2' completed successfully.
# Imputation for column 'FunctionalAssessment_0' completed successfully.
# Imputation for column 'FunctionalAssessment_3' completed successfully.
# Imputation for column 'FunctionalAssessment_1' completed successfully.
# Imputation for column 'FunctionalAssessment_2' completed successfully.
# Imputation for column 'MemoryComplaints_0' completed successfully.
# Imputation for column 'MemoryComplaints_3' completed successfully.
# Imputation for column 'MemoryComplaints_1' completed successfully.
# Imputation for column 'MemoryComplaints_2' completed successfully.
# Imputation for column 'BehavioralProblems_0' completed successfully.
# Imputation for column 'BehavioralProblems_3' completed successfully.
# Imputation for column 'BehavioralProblems_1' completed successfully.
# Imputation for column 'BehavioralProblems_2' completed successfully.
# Imputation for column 'ADL_0' completed successfully.
# Imputation for column 'ADL_3' completed successfully.
# Imputation for column 'ADL_1' completed successfully.
# Imputation for column 'ADL_2' completed successfully.
# Imputation for column 'Confusion_0' completed successfully.
# Imputation for column 'Confusion_3' completed successfully.
# Imputation for column 'Confusion_1' completed successfully.
# Imputation for column 'Confusion_2' completed successfully.
# Imputation for column 'Disorientation_0' completed successfully.
# Imputation for column 'Disorientation_3' completed successfully.
# Imputation for column 'Disorientation_1' completed successfully.
# Imputation for column 'Disorientation_2' completed successfully.
# Imputation for column 'PersonalityChanges_0' completed successfully.
# Imputation for column 'PersonalityChanges_3' completed successfully.
# Imputation for column 'PersonalityChanges_1' completed successfully.
# Imputation for column 'PersonalityChanges_2' completed successfully.
# Imputation for column 'DifficultyCompletingTasks_0' completed successfully.
# Imputation for column 'DifficultyCompletingTasks_3' completed successfully.
# Imputation for column 'DifficultyCompletingTasks_1' completed successfully.
# Imputation for column 'DifficultyCompletingTasks_2' completed successfully.
# Imputation for column 'Forgetfulness_0' completed successfully.
# Imputation for column 'Forgetfulness_3' completed successfully.
# Imputation for column 'Forgetfulness_1' completed successfully.
# Imputation for column 'Forgetfulness_2' completed successfully.
# Imputation for column 'HeadInjury_0' completed successfully.
# Imputation for column 'HeadInjury_3' completed successfully.
# Imputation for column 'HeadInjury_1' completed successfully.
# Imputation for column 'HeadInjury_2' completed successfully.
# Imputation for column 'EducationLevel_0' completed successfully.
# Imputation for column 'EducationLevel_3' completed successfully.
# Imputation for column 'EducationLevel_1' completed successfully.
# Imputation for column 'EducationLevel_2' completed successfully.
# Imputation for column 'Smoking_0' completed successfully.
# Imputation for column 'Smoking_3' completed successfully.
# Imputation for column 'Smoking_1' completed successfully.
# Imputation for column 'Smoking_2' completed successfully.
# Imputation for column 'AlcoholConsumption_0' completed successfully.
# Imputation for column 'AlcoholConsumption_3' completed successfully.
# Imputation for column 'AlcoholConsumption_1' completed successfully.
# Imputation for column 'AlcoholConsumption_2' completed successfully.
# Imputation for column 'PhysicalActivity_0' completed successfully.
# Imputation for column 'PhysicalActivity_3' completed successfully.
# Imputation for column 'PhysicalActivity_1' completed successfully.
# Imputation for column 'PhysicalActivity_2' completed successfully.
# Imputation for column 'DietQuality_0' completed successfully.
# Imputation for column 'DietQuality_3' completed successfully.
# Imputation for column 'DietQuality_1' completed successfully.
# Imputation for column 'DietQuality_2' completed successfully.
# Imputation for column 'SleepQuality_0' completed successfully.
# Imputation for column 'SleepQuality_3' completed successfully.
# Imputation for column 'SleepQuality_1' completed successfully.
# Imputation for column 'SleepQuality_2' completed successfully.

# %%
df_3 = df_2

# %%
#because it took 30 minutes to make this df, it is saved to a csv file so it can easily be read again when opening up ipynb again instead of having to do this all over
write_df_to_csv(df_3, 'analysis_2.csv')
# Out:
# DataFrame successfully written to analysis_2.csv

# %%
#drop these ethnicity columns since we are already looking at them per variable
df_3.drop(columns=['Ethnicity_0'], inplace=True)
df_3.drop(columns=['Ethnicity_1'], inplace=True)
df_3.drop(columns=['Ethnicity_2'], inplace=True)
df_3.drop(columns=['Ethnicity_3'], inplace=True)

# %%
#drop the ethnicity column names in the list with column names
predictors_2 = predictors_on_ethnicity
predictors_2.remove("Ethnicity_0")
predictors_2.remove("Ethnicity_1")
predictors_2.remove("Ethnicity_2")
predictors_2.remove("Ethnicity_3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 predictors_2 = predictors_on_ethnicity
# ----> 2 predictors_2.remove("Ethnicity_0")
#       3 predictors_2.remove("Ethnicity_1")
#       4 predictors_2.remove("Ethnicity_2")
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# Down here is the logistic regression fit again and the BIC used to determine the best model

# %%
# Define the target variable (Diagnosis) and predictor variables 
y = df_3['Diagnosis'].astype(int)  # Ensure target variable is numeric

# Create a list of all potential predictor variables
predictors = predictors_2

"""
# Function to fit logistic regression and calculate BIC
def fit_model(X):
    X_sm = sm.add_constant(X)  # Add a constant for the intercept term
    model_sm = sm.Logit(y, X_sm).fit(disp=0)  # Fit the logistic regression model
    return model_sm.bic, model_sm  # Return the BIC value and model
"""

def fit_model(X):
    X_sm = sm.add_constant(X)  # Add a constant for the intercept term
    try:
        model_sm = sm.Logit(y, X_sm).fit(disp=0)  # Fit the logistic regression model
        return model_sm.bic, model_sm  # Return the BIC value and model
    except np.linalg.LinAlgError:  # Catch singular matrix error
        print("Singular matrix error with predictors:", X.columns)
        return np.inf, None  # Return an infinite BIC value to discard this model
    
# Function to print the logistic regression formula
def print_model_formula(model, predictors):
    coef = model.params
    formula = f"y = {coef.iloc[0]:.4f}"  # Intercept
    for i, predictor in enumerate(predictors):
        formula += f" + ({coef.iloc[i + 1]:.4f} * {predictor})"
    print("Logistic Regression Formula:")
    print(formula)

# Initialize lists to store the BIC values and the predictors used
bic_values = []
best_bic = float('inf')
best_model = None
selected_predictors = []
remaining_predictors = set(predictors)

# Step 1: Find the best initial predictor
best_initial_bic = float('inf')
best_initial_predictor = None

for predictor in remaining_predictors:
    X = df_3[[predictor]]
    bic, _ = fit_model(X)
    if bic < best_initial_bic:
        best_initial_bic = bic
        best_initial_predictor = predictor

# Update lists and variables after selecting the first predictor
selected_predictors.append(best_initial_predictor)
bic_values.append(best_initial_bic)
best_bic = best_initial_bic
remaining_predictors.remove(best_initial_predictor)

# Step 2: Iteratively add predictors that improve the BIC
while remaining_predictors:
    best_new_bic = float('inf')
    best_new_predictor = None

    for predictor in remaining_predictors:
        X = df_3[selected_predictors + [predictor]]
        bic, _ = fit_model(X)
        if bic < best_new_bic:
            best_new_bic = bic
            best_new_predictor = predictor

    # Check if adding the new predictor improves the BIC
    if best_new_bic < best_bic:
        best_bic = best_new_bic
        selected_predictors.append(best_new_predictor)
        bic_values.append(best_bic)
        remaining_predictors.remove(best_new_predictor)

        # Save the current best model
        X_best = df_3[selected_predictors]
        X_best_sm = sm.add_constant(X_best)
        _, best_model = fit_model(X_best)
    else:
        break  # Stop if no improvement

# Step 3: Add remaining predictors to complete the graph
for predictor in remaining_predictors:
    selected_predictors.append(predictor)
    X = df_3[selected_predictors]
    bic, _ = fit_model(X)
    bic_values.append(bic)

# Print the best combination of predictors and its BIC
print(f"Best combination of predictors: {selected_predictors[:bic_values.index(best_bic) + 1]}")
print(f"Best BIC: {best_bic}")

# Print the summary of the best model
print(best_model.summary())

# Print the logistic regression formula for the best model
print_model_formula(best_model, selected_predictors[:bic_values.index(best_bic) + 1])

# Visualization: Plot the number of predictors vs BIC values
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(bic_values) + 1), bic_values, marker='o', linestyle='-', color='b')
plt.title('BIC vs Number of Predictors')
plt.xlabel('Number of Predictors')
plt.ylabel('BIC')
plt.xticks(range(1, len(bic_values) + 1, 10))
plt.axvline(x=bic_values.index(best_bic) + 1, color='r', linestyle='--', label='Best Model')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Best combination of predictors: ['FunctionalAssessment_3', 'FunctionalAssessment_2', 'MemoryComplaints_1', 'ADL_3', 'FunctionalAssessment_0', 'ADL_1', 'MemoryComplaints_2', 'FunctionalAssessment_1', 'ADL_2', 'ADL_0', 'MemoryComplaints_0', 'BehavioralProblems_0', 'MMSE_0', 'MMSE_2', 'MemoryComplaints_3', 'MMSE_1', 'SystolicBP_2', 'PhysicalActivity_2', 'BehavioralProblems_1', 'CholesterolLDL_2', 'DietQuality_3', 'CholesterolLDL_3', 'PersonalityChanges_0', 'CholesterolHDL_2', 'Hypertension_2', 'Hypertension_3', 'Forgetfulness_3', 'MMSE_3', 'Diabetes_3', 'DiastolicBP_2']
# Best BIC: 702.6041719288762
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Diagnosis   No. Observations:                 2149
# Model:                          Logit   Df Residuals:                     2118
# Method:                           MLE   Df Model:                           30
# Date:                Wed, 04 Dec 2024   Pseudo R-squ.:                  0.8336
# Time:                        22:08:46   Log-Likelihood:                -232.37
# converged:                       True   LL-Null:                       -1396.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     19.4902      1.725     11.300      0.000      16.110      22.871
# FunctionalAssessment_3    -0.4459      0.049     -9.149      0.000      -0.541      -0.350
# FunctionalAssessment_2    -0.4722      0.052     -9.111      0.000      -0.574      -0.371
# MemoryComplaints_1         2.3741      0.329      7.220      0.000       1.730       3.019
# ADL_3                     -0.3940      0.048     -8.197      0.000      -0.488      -0.300
# FunctionalAssessment_0    -0.4001      0.051     -7.912      0.000      -0.499      -0.301
# ADL_1                     -0.3037      0.045     -6.709      0.000      -0.392      -0.215
# MemoryComplaints_2         1.7006      0.295      5.769      0.000       1.123       2.278
# FunctionalAssessment_1    -0.2833      0.045     -6.274      0.000      -0.372      -0.195
# ADL_2                     -0.3190      0.046     -6.872      0.000      -0.410      -0.228
# ADL_0                     -0.3380      0.046     -7.422      0.000      -0.427      -0.249
# MemoryComplaints_0         1.7923      0.307      5.846      0.000       1.191       2.393
# BehavioralProblems_0       2.1675      0.339      6.389      0.000       1.503       2.832
# MMSE_0                    -0.0787      0.016     -5.069      0.000      -0.109      -0.048
# MMSE_2                    -0.1027      0.016     -6.241      0.000      -0.135      -0.070
# MemoryComplaints_3         1.8360      0.327      5.619      0.000       1.196       2.476
# MMSE_1                    -0.0845      0.015     -5.584      0.000      -0.114      -0.055
# SystolicBP_2              -0.0216      0.005     -4.323      0.000      -0.031      -0.012
# PhysicalActivity_2         0.1789      0.043      4.185      0.000       0.095       0.263
# BehavioralProblems_1       1.4416      0.352      4.093      0.000       0.751       2.132
# CholesterolLDL_2          -0.0107      0.003     -3.710      0.000      -0.016      -0.005
# DietQuality_3             -0.1666      0.042     -3.951      0.000      -0.249      -0.084
# CholesterolLDL_3          -0.0087      0.003     -2.975      0.003      -0.014      -0.003
# PersonalityChanges_0      -1.4392      0.386     -3.731      0.000      -2.195      -0.683
# CholesterolHDL_2          -0.0194      0.005     -3.699      0.000      -0.030      -0.009
# Hypertension_2             1.0945      0.324      3.377      0.001       0.459       1.730
# Hypertension_3             1.1712      0.365      3.208      0.001       0.456       1.887
# Forgetfulness_3           -0.9246      0.307     -3.015      0.003      -1.526      -0.324
# MMSE_3                    -0.0530      0.015     -3.528      0.000      -0.082      -0.024
# Diabetes_3                 1.1830      0.371      3.193      0.001       0.457       1.909
# DiastolicBP_2              0.0220      0.008      2.802      0.005       0.007       0.037
# ==========================================================================================
#
# Possibly complete quasi-separation: A fraction 0.22 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Logistic Regression Formula:
# y = 19.4902 + (-0.4459 * FunctionalAssessment_3) + (-0.4722 * FunctionalAssessment_2) + (2.3741 * MemoryComplaints_1) + (-0.3940 * ADL_3) + (-0.4001 * FunctionalAssessment_0) + (-0.3037 * ADL_1) + (1.7006 * MemoryComplaints_2) + (-0.2833 * FunctionalAssessment_1) + (-0.3190 * ADL_2) + (-0.3380 * ADL_0) + (1.7923 * MemoryComplaints_0) + (2.1675 * BehavioralProblems_0) + (-0.0787 * MMSE_0) + (-0.1027 * MMSE_2) + (1.8360 * MemoryComplaints_3) + (-0.0845 * MMSE_1) + (-0.0216 * SystolicBP_2) + (0.1789 * PhysicalActivity_2) + (1.4416 * BehavioralProblems_1) + (-0.0107 * CholesterolLDL_2) + (-0.1666 * DietQuality_3) + (-0.0087 * CholesterolLDL_3) + (-1.4392 * PersonalityChanges_0) + (-0.0194 * CholesterolHDL_2) + (1.0945 * Hypertension_2) + (1.1712 * Hypertension_3) + (-0.9246 * Forgetfulness_3) + (-0.0530 * MMSE_3) + (1.1830 * Diabetes_3) + (0.0220 * DiastolicBP_2)

# %% [markdown]
# From here on, the same is done as above. So the logistic regression is fit with the help of BIC. However, since making the dataframe with the columns seperated on ethnicity took very long, if the outputs are somehow deleted, down here is a quicker version that reads the already edited csv file in a dataframe. As you can see all the way at the bottom, the results are the same.

# %%
# Reading the CSV file into a DataFrame
file_path = 'analysis_2.csv'  # Replace with your file path if different
alzheimers_data_new_columns = pd.read_csv(file_path)

# %%
def log_regression_bic(df, predictors):
    
    # Define the target variable (Diagnosis) and predictor variables 
    y = df['Diagnosis'].astype(int)  # Ensure target variable is numeric

    # Create a list of all potential predictor variables
    predictors = predictors

    """
    # Function to fit logistic regression and calculate BIC
    def fit_model(X):
        X_sm = sm.add_constant(X)  # Add a constant for the intercept term
        model_sm = sm.Logit(y, X_sm).fit(disp=0)  # Fit the logistic regression model
        return model_sm.bic, model_sm  # Return the BIC value and model
    """

    def fit_model(X):
        X_sm = sm.add_constant(X)  # Add a constant for the intercept term
        try:
            model_sm = sm.Logit(y, X_sm).fit(disp=0)  # Fit the logistic regression model
            return model_sm.bic, model_sm  # Return the BIC value and model
        except np.linalg.LinAlgError:  # Catch singular matrix error
            print("Singular matrix error with predictors:", X.columns)
            return np.inf, None  # Return an infinite BIC value to discard this model
        
    # Function to print the logistic regression formula
    def print_model_formula(model, predictors):
        coef = model.params
        formula = f"y = {coef.iloc[0]:.4f}"  # Intercept
        for i, predictor in enumerate(predictors):
            formula += f" + ({coef.iloc[i + 1]:.4f} * {predictor})"
        print("Logistic Regression Formula:")
        print(formula)

    # Initialize lists to store the BIC values and the predictors used
    bic_values = []
    best_bic = float('inf')
    best_model = None
    selected_predictors = []
    remaining_predictors = set(predictors)

    # Step 1: Find the best initial predictor
    best_initial_bic = float('inf')
    best_initial_predictor = None

    for predictor in remaining_predictors:
        X = df[[predictor]]
        bic, _ = fit_model(X)
        if bic < best_initial_bic:
            best_initial_bic = bic
            best_initial_predictor = predictor

    # Update lists and variables after selecting the first predictor
    selected_predictors.append(best_initial_predictor)
    bic_values.append(best_initial_bic)
    best_bic = best_initial_bic
    remaining_predictors.remove(best_initial_predictor)

    # Step 2: Iteratively add predictors that improve the BIC
    while remaining_predictors:
        best_new_bic = float('inf')
        best_new_predictor = None

        for predictor in remaining_predictors:
            X = df[selected_predictors + [predictor]]
            bic, _ = fit_model(X)
            if bic < best_new_bic:
                best_new_bic = bic
                best_new_predictor = predictor

        # Check if adding the new predictor improves the BIC
        if best_new_bic < best_bic:
            best_bic = best_new_bic
            selected_predictors.append(best_new_predictor)
            bic_values.append(best_bic)
            remaining_predictors.remove(best_new_predictor)

            # Save the current best model
            X_best = df[selected_predictors]
            X_best_sm = sm.add_constant(X_best)
            _, best_model = fit_model(X_best)
        else:
            break  # Stop if no improvement

    # Step 3: Add remaining predictors to complete the graph
    for predictor in remaining_predictors:
        selected_predictors.append(predictor)
        X = df[selected_predictors]
        bic, _ = fit_model(X)
        bic_values.append(bic)

    # Print the best combination of predictors and its BIC
    print(f"Best combination of predictors: {selected_predictors[:bic_values.index(best_bic) + 1]}")
    print(f"Best BIC: {best_bic}")

    # Print the summary of the best model
    print(best_model.summary())

    # Print the logistic regression formula for the best model
    print_model_formula(best_model, selected_predictors[:bic_values.index(best_bic) + 1])

    # Visualization: Plot the number of predictors vs BIC values
    plt.figure(figsize=(8, 6))
    plt.plot(range(1, len(bic_values) + 1), bic_values, marker='o', linestyle='-', color='b')
    plt.title('BIC vs Number of Predictors')
    plt.xlabel('Number of Predictors')
    plt.ylabel('BIC')
    plt.xticks(range(1, len(bic_values) + 1, 10))
    plt.axvline(x=bic_values.index(best_bic) + 1, color='r', linestyle='--', label='Best Model')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
alzheimers_data_new_columns.columns = alzheimers_data_new_columns.columns.str.strip()
alzheimers_data_new_columns.drop(columns=['Ethnicity_0'], inplace=True)
alzheimers_data_new_columns.drop(columns=['Ethnicity_1'], inplace=True)
alzheimers_data_new_columns.drop(columns=['Ethnicity_2'], inplace=True)
alzheimers_data_new_columns.drop(columns=['Ethnicity_3'], inplace=True)
# Out:
# ['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality', 'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease', 'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP', 'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment', 'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion', 'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks', 'Forgetfulness', 'Diagnosis', 'DoctorInCharge', 'Age_0', 'Age_3', 'Age_1', 'Age_2', 'Gender_0', 'Gender_3', 'Gender_1', 'Gender_2', 'Ethnicity_0', 'Ethnicity_3', 'Ethnicity_1', 'Ethnicity_2', 'BMI_0', 'BMI_3', 'BMI_1', 'BMI_2', 'FamilyHistoryAlzheimers_0', 'FamilyHistoryAlzheimers_3', 'FamilyHistoryAlzheimers_1', 'FamilyHistoryAlzheimers_2', 'CardiovascularDisease_0', 'CardiovascularDisease_3', 'CardiovascularDisease_1', 'CardiovascularDisease_2', 'Diabetes_0', 'Diabetes_3', 'Diabetes_1', 'Diabetes_2', 'Depression_0', 'Depression_3', 'Depression_1', 'Depression_2', 'Hypertension_0', 'Hypertension_3', 'Hypertension_1', 'Hypertension_2', 'SystolicBP_0', 'SystolicBP_3', 'SystolicBP_1', 'SystolicBP_2', 'DiastolicBP_0', 'DiastolicBP_3', 'DiastolicBP_1', 'DiastolicBP_2', 'CholesterolTotal_0', 'CholesterolTotal_3', 'CholesterolTotal_1', 'CholesterolTotal_2', 'CholesterolLDL_0', 'CholesterolLDL_3', 'CholesterolLDL_1', 'CholesterolLDL_2', 'CholesterolHDL_0', 'CholesterolHDL_3', 'CholesterolHDL_1', 'CholesterolHDL_2', 'CholesterolTriglycerides_0', 'CholesterolTriglycerides_3', 'CholesterolTriglycerides_1', 'CholesterolTriglycerides_2', 'MMSE_0', 'MMSE_3', 'MMSE_1', 'MMSE_2', 'FunctionalAssessment_0', 'FunctionalAssessment_3', 'FunctionalAssessment_1', 'FunctionalAssessment_2', 'MemoryComplaints_0', 'MemoryComplaints_3', 'MemoryComplaints_1', 'MemoryComplaints_2', 'BehavioralProblems_0', 'BehavioralProblems_3', 'BehavioralProblems_1', 'BehavioralProblems_2', 'ADL_0', 'ADL_3', 'ADL_1', 'ADL_2', 'Confusion_0', 'Confusion_3', 'Confusion_1', 'Confusion_2', 'Disorientation_0', 'Disorientation_3', 'Disorientation_1', 'Disorientation_2', 'PersonalityChanges_0', 'PersonalityChanges_3', 'PersonalityChanges_1', 'PersonalityChanges_2', 'DifficultyCompletingTasks_0', 'DifficultyCompletingTasks_3', 'DifficultyCompletingTasks_1', 'DifficultyCompletingTasks_2', 'Forgetfulness_0', 'Forgetfulness_3', 'Forgetfulness_1', 'Forgetfulness_2', 'HeadInjury_0', 'HeadInjury_3', 'HeadInjury_1', 'HeadInjury_2', 'EducationLevel_0', 'EducationLevel_3', 'EducationLevel_1', 'EducationLevel_2', 'Smoking_0', 'Smoking_3', 'Smoking_1', 'Smoking_2', 'AlcoholConsumption_0', 'AlcoholConsumption_3', 'AlcoholConsumption_1', 'AlcoholConsumption_2', 'PhysicalActivity_0', 'PhysicalActivity_3', 'PhysicalActivity_1', 'PhysicalActivity_2', 'DietQuality_0', 'DietQuality_3', 'DietQuality_1', 'DietQuality_2', 'SleepQuality_0', 'SleepQuality_3', 'SleepQuality_1', 'SleepQuality_2']

# %%
log_regression_bic(df=alzheimers_data_new_columns, predictors=predictors_2)
# Out:
# Best combination of predictors: ['FunctionalAssessment_3', 'FunctionalAssessment_2', 'MemoryComplaints_1', 'ADL_3', 'FunctionalAssessment_0', 'ADL_1', 'MemoryComplaints_2', 'FunctionalAssessment_1', 'ADL_2', 'ADL_0', 'MemoryComplaints_0', 'BehavioralProblems_0', 'MMSE_0', 'MMSE_2', 'MemoryComplaints_3', 'MMSE_1', 'SystolicBP_2', 'PhysicalActivity_2', 'BehavioralProblems_1', 'CholesterolLDL_2', 'DietQuality_3', 'CholesterolLDL_3', 'PersonalityChanges_0', 'CholesterolHDL_2', 'Hypertension_2', 'Hypertension_3', 'Forgetfulness_3', 'MMSE_3', 'Diabetes_3', 'DiastolicBP_2']
# Best BIC: 702.6041719288762
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Diagnosis   No. Observations:                 2149
# Model:                          Logit   Df Residuals:                     2118
# Method:                           MLE   Df Model:                           30
# Date:                Thu, 05 Dec 2024   Pseudo R-squ.:                  0.8336
# Time:                        09:21:33   Log-Likelihood:                -232.37
# converged:                       True   LL-Null:                       -1396.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     19.4902      1.725     11.300      0.000      16.110      22.871
# FunctionalAssessment_3    -0.4459      0.049     -9.149      0.000      -0.541      -0.350
# FunctionalAssessment_2    -0.4722      0.052     -9.111      0.000      -0.574      -0.371
# MemoryComplaints_1         2.3741      0.329      7.220      0.000       1.730       3.019
# ADL_3                     -0.3940      0.048     -8.197      0.000      -0.488      -0.300
# FunctionalAssessment_0    -0.4001      0.051     -7.912      0.000      -0.499      -0.301
# ADL_1                     -0.3037      0.045     -6.709      0.000      -0.392      -0.215
# MemoryComplaints_2         1.7006      0.295      5.769      0.000       1.123       2.278
# FunctionalAssessment_1    -0.2833      0.045     -6.274      0.000      -0.372      -0.195
# ADL_2                     -0.3190      0.046     -6.872      0.000      -0.410      -0.228
# ADL_0                     -0.3380      0.046     -7.422      0.000      -0.427      -0.249
# MemoryComplaints_0         1.7923      0.307      5.846      0.000       1.191       2.393
# BehavioralProblems_0       2.1675      0.339      6.389      0.000       1.503       2.832
# MMSE_0                    -0.0787      0.016     -5.069      0.000      -0.109      -0.048
# MMSE_2                    -0.1027      0.016     -6.241      0.000      -0.135      -0.070
# MemoryComplaints_3         1.8360      0.327      5.619      0.000       1.196       2.476
# MMSE_1                    -0.0845      0.015     -5.584      0.000      -0.114      -0.055
# SystolicBP_2              -0.0216      0.005     -4.323      0.000      -0.031      -0.012
# PhysicalActivity_2         0.1789      0.043      4.185      0.000       0.095       0.263
# BehavioralProblems_1       1.4416      0.352      4.093      0.000       0.751       2.132
# CholesterolLDL_2          -0.0107      0.003     -3.710      0.000      -0.016      -0.005
# DietQuality_3             -0.1666      0.042     -3.951      0.000      -0.249      -0.084
# CholesterolLDL_3          -0.0087      0.003     -2.975      0.003      -0.014      -0.003
# PersonalityChanges_0      -1.4392      0.386     -3.731      0.000      -2.195      -0.683
# CholesterolHDL_2          -0.0194      0.005     -3.699      0.000      -0.030      -0.009
# Hypertension_2             1.0945      0.324      3.377      0.001       0.459       1.730
# Hypertension_3             1.1712      0.365      3.208      0.001       0.456       1.887
# Forgetfulness_3           -0.9246      0.307     -3.015      0.003      -1.526      -0.324
# MMSE_3                    -0.0530      0.015     -3.528      0.000      -0.082      -0.024
# Diabetes_3                 1.1830      0.371      3.193      0.001       0.457       1.909
# DiastolicBP_2              0.0220      0.008      2.802      0.005       0.007       0.037
# ==========================================================================================
#
# Possibly complete quasi-separation: A fraction 0.22 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Logistic Regression Formula:
# y = 19.4902 + (-0.4459 * FunctionalAssessment_3) + (-0.4722 * FunctionalAssessment_2) + (2.3741 * MemoryComplaints_1) + (-0.3940 * ADL_3) + (-0.4001 * FunctionalAssessment_0) + (-0.3037 * ADL_1) + (1.7006 * MemoryComplaints_2) + (-0.2833 * FunctionalAssessment_1) + (-0.3190 * ADL_2) + (-0.3380 * ADL_0) + (1.7923 * MemoryComplaints_0) + (2.1675 * BehavioralProblems_0) + (-0.0787 * MMSE_0) + (-0.1027 * MMSE_2) + (1.8360 * MemoryComplaints_3) + (-0.0845 * MMSE_1) + (-0.0216 * SystolicBP_2) + (0.1789 * PhysicalActivity_2) + (1.4416 * BehavioralProblems_1) + (-0.0107 * CholesterolLDL_2) + (-0.1666 * DietQuality_3) + (-0.0087 * CholesterolLDL_3) + (-1.4392 * PersonalityChanges_0) + (-0.0194 * CholesterolHDL_2) + (1.0945 * Hypertension_2) + (1.1712 * Hypertension_3) + (-0.9246 * Forgetfulness_3) + (-0.0530 * MMSE_3) + (1.1830 * Diabetes_3) + (0.0220 * DiastolicBP_2)

# %% [markdown]
# Doing Logistic regression based on dummy variable:

# %%
#creating a dataframe with the dummy variable:
